# %% [markdown]
# <a href="https://colab.research.google.com/github/MDSOHELRANA12/MDSOHELRANA12/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1. Owner & Primary Payment Setup
Platform Owner: MD SOHEL RANARANA
Master Bank Account: nsave USD (Clear Bank, London, GB)
IBAN: GB56CLRB04281298407970
SWIFT/BIC: CLRBGB22XXXXXX
Integration: All global revenue from Google Ads must be funneled into this account.
2. Tiered MonMonetizMonMonetizationMonMonetizationetizationetizationationMonMonetizationetizationetization Algorithm (YouTube Style)
RequirementRequirementRequirementRequirement: User must upload 1 unique video daily.
Revenue: 100% of ad revenue goes to the Owner. User receives $0.
Phase 2 (Half Monetization):
Condition: After 6 months of active uploads + 1,000 Followers.
Revenue Split: 80% Owner / 20% User.
Phase 3 (Full Monetization):
Condition: After 1 year of active uploads + 1,000 Followers.
Revenue Split: 60% Owner / 40% User.
3. Penalty & Violation System
The 40-Day Rule: If a user violates community guidelines (Copyright, Fake views, Inactivity), their payout is instantly frozen for 40 days.
Owner Benefit: During these 40 days, the user's 20% or 40% share is canceled, and 100% of the revenue is redirected to the Owner's account.
4. Automation & Verification
Google Payouts API: Integrate Google API to verify user identity and automate bank/bKash transfers.
Admin Dashboard: Owner must have a private dashboard to see real-time earnings from every user and control the split percentage.
Smart Counter: A system that tracks "Daily Upload Streaks" and automatically flags users who miss a day.

9. Humane Penalty System (The 3-Month Rule):
Instead of termination, if a user hits 3 copyright/policy strikes, suspend their earnings for 90 days.
The account remains active, and videos keep running, but 100% of the revenue during these 90 days is automatically routed to the Owner's nsave account. After 90 days, monetization is automatically restored.
10. Advanced Algorithm & High-Speed Loading:
Optimize video delivery for zero buffering and seamless uploads.
The algorithm must prioritize high impressions for every new video to prevent view drops.
11. Strategic Ad Placement:
Interstitials: Show 1 full-screen ad after every 5 short video scrolls.
Sticky Banner: A permanent small banner ad on the UI. 100% of this banner revenue belongs solely to the Owner.
12. Ad Quality Control (Safe & Premium):
Use Google AdMob filters to block all sexual, low-quality, or sensitive ad categories.
Only allow high-CPM and family-friendly premium ads to ensure maximum revenue and user safety.



13. Global Access & Restrictions:
Open for all countries except Israel (Strictly Blocked).
Support for all international phone number country codes for OTP verification.
14. Seamless Payout System:
Date: Automated payouts between the 4th and 5th of every month, regardless of holidays.
Local Banking: Enable local bank transfers for all countries.
Bangladesh Special: Full support for bKash, Nagad, Rocket, and all local government/private banks to help low-income users. No Master/Visa card required for withdrawal.
15. User Onboarding & Retention:
First Payment Rule: New users must upload a "First Payment Celebration" video on the platform to motivate others.
Simple Login: Phone number + Firebase/Google OTP verification only.
16. AI Chatbot & Community Safety:
No live video streaming. Integrated AI Chatbot for private conversations.
Zero tolerance for abuse or slang; automated ban for toxic language.
17. Content Governance:
Strictly prohibit violence, political conspiracy, threats, or harmful content.
All operations must strictly follow Google's Global Policies and Terms of Service.
18. Future Asset Management:
The app will never be sold. In case of financial crisis, the owner will seek direct partnership with Google instead of third-party buyers.



20. In-House OTP & Data Sovereignty (Non-Firebase Model):
Custom Code Generator: Develop a local algorithm to generate unique OTP codes directly within the platform's backend without relying on Google Firebase.
Private Database Management: Store all user details, logs, and transaction history in a private, secure database (e.g., MongoDB/PostgreSQL) under the owner's direct control.
Google Cloud Sync: Use Google APIs only for data synchronization and high-level verification, ensuring all raw data stays within the platform's internal server.
Direct SMS Gateway Integration: Use a dedicated SMS API (Twilio/Vonage) to deliver internally generated codes to users globally, bypassing Firebase's complex setup while maintaining Google's security standards.

26. Automatic Google Synchronization (The Direct Link)
One-Time Integration: Once the owner inputs the Google Publisher ID or API Key into the MDSOHELRANA BT AI dashboard, the platform must automatically generate the necessary background files (ads.txt, security-meta-tags).
Auto-Handshake: The platform will use its built-in API to tell Google: "I am MDSOHELRANA BT AI, and here is the key provided by the owner." * Instant Verification: This process will allow Google to recognize the owner and the platform instantly without the owner ever needing to touch any code or hosting settings again.
Persistent Identity: Once this link is established, the platform and Google will stay connected forever as trusted partners.


27. Multi-Bank Backup & Dynamic Payout Management:
Primary & Secondary Bank Options: Within the Owner's Profile, provide multiple slots to add different bank accounts (e.g., Slot 1: nsave, Slot 2: Local Bangladesh Bank, Slot 3: Payoneer/Wise).
Instant SwitcSwitchSwitcSwitchhh: The owner must be able to switch the primary payout destination with one click. If one bank has issues, the revenue will automatically flow into the backup bank.
Global Flexibility: The system must support adding international banks (IBAN/SWIFT) and local mobile financial services (bKash/Nagad) simultaneously for the owner’s convenience.
Security Lock: Any change to the owner’s bank details must require a high-security verification (like a secret Master PIN or Phone OTP) to prevent hacking.

Payout Continuity Guarantee:
In the eveventevevententent of a bank account change by the owner, the platform’s automated payout system must remain unaffected.
The system must allow for a seamless transition between old and new banking partners (Master/Visa/Local) without interrupting the payment cycle of global users.



Global SWIFT Integration (Primary):
Use the UK-based SWIFT/IBAN (GB56CLRB04281298407970) as the main channel for receiving Google AdSense revenue.
Even though it is a GB (UK) account, it is fully capable of receiving USD payments from the USA via the SWIFT network.
This ensures the MDSOHELRANA BT AI platform stays connected to the global banking grid.



35. Manual Traffic & Algorithm Control (The Master Switch):
Impression Control Toggle: The Owner Dashboard must have a manual slider or toggle to control the "Algorithm Speed."
High-Speed Mode (ON): Boosts video impressions and virality globally to maximize revenue.
Stability Mode (OFF/Down): Manually slows down the algorithm's push to maintain a steady, lower-traffic flow when needed.
Owner’s Sovereignty: Only the Master Owner (MD SOHEL RANA) can access these controls. No automated system can override the owner's manual setting for traffic "Up" or "Down."
36. Adaptive UI Modes (Light & Dark Themes):
Dual-Theme Interface: The platform must support two primary visual modes:
White Mode (Clean & Professional): For high visibility during daylight.
Dark Mode (Premium Black): A sleek, black-themed interface for a modern look and battery efficiency.
One-Tap Toggle: Users must be able to switch between Light and Dark modes instantly from the settings menu.
37. Viral Impression Engine (Impression Booster):
Initial Kick: Every new video must receive a guaranteed "Initial Impression Boost" of 1,000+ to ensure it doesn't get stuck at zero views.
Viral Logic: If engagement (likes/comments) is high, the system will automatically double the push to take the video to a global audience.
38. AI Security & Support Assistant:
Integrated Support Bot: A 24/7 AI chatbot will handle user inquiries about monetization, rules, and technical issues.
Policy Enforcement: The bot will automatically scan for banned content (e.g., Israel-related or harmful content) and flag it for the owner’s review.
39. Google AdSense Handshake & English Deployment:
Automated Ad Activation: The backend must be coded to "Auto-Wake" the Google AdSense API once the owner inputs the site details.
English Backend Standards: To prevent any system glitches and maintain global standards, the entire source code, database architecture, and primary UI must be in English.

41. VIP Media Room & Celebrity Connect (Direct Video Access):
Celebrity Hotline: A dedicated video chat portal for the platform's top-tier creators and celebrities. They can request a direct video meeting with the Owner (MD SOHEL RANA) to share ideas, feedback, or collaborations.
Equality Protocol: Unlike TikTok or Facebook, this platform treats all creators fairly. High-performing users get "VIP Verified" status, granting them access to the owner's private video communication channel.
High-Quality Video Link: Integrated encrypted video calling (WebRTC technology) for lag-free, face-to-face conversations.
42. Global Corporate Deal-Room (Business & Partnership):
B2B Meeting Hub: A high-security video conferencing room designed specifically for big companies (like Google, Coke, or Samsung) to negotiate direct ad deals or partnerships with the owner.
Smart Scheduling: Companies can book a slot for a video meeting. The owner can accept or decline these high-level corporate calls from the Admin Dashboard.
100% Secure & Private: These meetings are end-to-end encrypted and will never be recorded or leaked, ensuring total business confidentiality.

44. Google Cloud Deployment & Scalability:
Use the Google Cloud Free Tier ($300 Credit) to host the platform initially.
Deploy the backend using Docker or Google App Engine for high-speed performance and global accessibility.
Ensure the platform can be accessed via a temporary IP address during development and seamlessly linked to a custom domain once ready.
The system must be optimized to run 24/7 without crashing, utilizing Google's high-speed global network

46. Ghost-Mode Code Generator & Master Vault:
Secret IDE (Code Studio): The Owner’s Dashboard must contain a hidden, password-protected "Code Studio." No user, staff, or celebrity can see or access this.
Stealth Generation: When the owner gives a command to the internal AI, it must generate the full source code within this hidden vault. The logic must be invisible to search engines and external hackers.
Instant Export (ZIP Download): The system must have a "One-Click Export" button. Once the code is ready, the owner can convert the entire project into a .ZIP or .JSON file and download it directly to their mobile device for offline backup.
No Logs Policy: The platform will not store any history of the generated codes in the main server; once downloaded or cleared by the owner, the data must be wiped to ensure 100% secrecy.

48. Invisible Master Identity & Ghost Profile:
Public Persona vs. Secret Control: While the owner’s name (MD SOHEL RANA) and photos may be visible to the world as the platform's face, the actual Admin Dashboard and Management Tools must remain 100% invisible.
Master Vault Access: No one can "search" for the owner's login page. It will be a hidden URL. Only by entering the secret master key S$s123456789112233 can the owner unlock the interface to see backend data, user logs, and earnings.
Read-Only vs. Full Control: To the world, your profile will look like a "Verified Legend," but for you (the owner), it will be a control center where you can edit anything, write new rules, and monitor global traffic in total silence.
Zero-Interference: No user or staff can send messages or "edit requests" to this master profile unless the owner initiates the contact through the VIP Video Room
# Out:
#   File "/tmp/ipykernel_21847/44994176.py", line 26
#     The account remains active, and videos keep running, but 100% of the revenue during these 90 days is automatically routed to the Owner's nsave account. After 90 days, monetization is automatically restored.
#                                                                                                                                           ^
# SyntaxError: unterminated string literal (detected at line 26)
